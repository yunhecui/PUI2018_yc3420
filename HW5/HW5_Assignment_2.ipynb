# %%
#author: yc3420, this is an individual work by Yunhe Cui, using reference files from PUI 2018
#this cell is for the python 2&3 compatible
from __future__ import print_function, division
SQL_SOURCE = 'https://fb55.carto.com/api/v2/sql?q=SELECT'


try:
    import urllib as ulib
except ImportError:
    import urllib3 as ulib

try:
    from StringIO import BytesIO as io
except ImportError:
    from io import BytesIO as io

try:
    from urllib import urlencode as urlencode
except ImportError:
    from urllib.parse import urlencode as urlencode
    
try:
    from urllib import urlopen as urlopen
except ImportError:
    from urllib.request import urlopen as urlopen
    
try:
    from urllib2 import HTTPError as HTTPError
except ImportError:
    from urllib.error import HTTPError as HTTPError

import ast
import pandas as pd
import geopy.distance
# import StringIO
# import urllib
# import urllib2

def queryCartoDB(query, format='CSV', source=SQL_SOURCE):
    '''queries carto datasets from a given carto account
    Arguments: 
    query - string: a valid sql query string
    format - outlut format  OPTIONAL (default CSV)
    source - a valid sql api endpoint OPTIONAL (default carto fb55 account)
    Returns:
    the return of the sql query AS A STRING
    NOTES:
    designed for the carto API, tested only with CSV return format'''
    
    data = urlencode({'format': format, 'q': query}).encode("utf-8")
    try:
        response = urlopen(source, data)
    except HTTPError as e:
        raise ValueError('\n'.join(ast.literal_eval(e.readline())['error']))
    except Exception:
        raise 
    return response.read()

def get_data(query):
     try:
         return pd.read_csv(io(queryCartoDB(query)), sep=',')
     except ValueError as v:
         print (str(v))

# %%
test = '''
SELECT *
FROM fb55.citibike;
'''

# %%
pd.read_csv(io(queryCartoDB(test)), sep=',')
# Out:
#        the_geom        start_station_name  the_geom_webmercator  field_1  \
# 0           NaN        E 20 St & Park Ave                   NaN      175
# 1           NaN          W 43 St & 10 Ave                   NaN     1159
# 2           NaN         E 6 St & Avenue B                   NaN     2827
# 3           NaN           E 12 St & 3 Ave                   NaN     4961
# 4           NaN           W 41 St & 8 Ave                   NaN     6156
# 5           NaN           5 Ave & E 29 St                   NaN     7433
# 6           NaN      Allen St & Hester St                   NaN     7779
# 7           NaN           E 39 St & 3 Ave                   NaN     8327
# 8           NaN          10 Ave & W 28 St                   NaN     9435
# 9           NaN            E 2 St & 2 Ave                   NaN    10472
# 10          NaN           1 Ave & E 44 St                   NaN    10931
# 11          NaN           W 45 St & 6 Ave                   NaN    11361
# ...

# %% [markdown]
# ### Task 1 - Familiarize with SQL Clauses

# %%
# Sort data by start_station_id, tripduration. 
# Only checking trips with duration <= 3 hours

query1_1 = '''
SELECT start_station_id 
FROM fb55.citibike
WHERE tripduration <= 10800'''
table1_1 = get_data(query1_1)
table1_1.head()
# Out:
#    start_station_id  Unnamed: 1
# 0               503         NaN
# 1               515         NaN
# 2               317         NaN
# 3               483         NaN
# 4               477         NaN

# %%
#Only show the last 10 records

query1_2 = '''
SELECT * 
FROM fb55.citibike 
ORDER BY cartodb_id 
DESC LIMIT 10'''
get_data(query1_2)
# Out:
#    the_geom     start_station_name  the_geom_webmercator  field_1  \
# 0       NaN         E 4 St & 2 Ave                   NaN    46199
# 1       NaN     Carmine St & 6 Ave                   NaN    46198
# 2       NaN        5 Ave & E 29 St                   NaN    46197
# 3       NaN        5 Ave & E 29 St                   NaN    46196
# 4       NaN        W 20 St & 8 Ave                   NaN    46195
# 5       NaN        1 Ave & E 44 St                   NaN    46194
# 6       NaN        E 20 St & 2 Ave                   NaN    46193
# 7       NaN  Warren St & Church St                   NaN    46192
# 8       NaN       W 47 St & 10 Ave                   NaN    46191
# 9       NaN        W 17 St & 8 Ave                   NaN    46190
#
#    start_station_longitude  tripduration               starttime  \
# 0               -73.989780           917  2015-02-07 23:59:00+00
# 1               -74.002150           548  2015-02-07 23:58:00+00
# ...

# %%
# Only show the top 10 records
query1_2_1 = '''
SELECT * 
FROM fb55.citibike 
ORDER BY cartodb_id 
ASC LIMIT 10'''
get_data(query1_2_1)
# Out:
#    the_geom                 start_station_name  the_geom_webmercator  field_1  \
# 0       NaN                    8 Ave & W 31 St                   NaN       70
# 1       NaN                 E 17 St & Broadway                   NaN       71
# 2       NaN  Grand Army Plaza & Central Park S                   NaN       72
# 3       NaN                  6 Ave & Broome St                   NaN       73
# 4       NaN        Lawrence St & Willoughby St                   NaN       74
# 5       NaN       Willoughby Ave & Walworth St                   NaN       75
# 6       NaN                    W 56 St & 6 Ave                   NaN       76
# 7       NaN                     E 4 St & 2 Ave                   NaN       77
# 8       NaN           Washington Pl & Broadway                   NaN       78
# 9       NaN              Greenwich Ave & 8 Ave                   NaN       79
#
#    start_station_longitude  tripduration               starttime  \
# ...

# %%
# List all unique start_station_id values
query1_3 = '''
SELECT DISTINCT start_station_id 
FROM fb55.citibike
'''
get_data(query1_3)
# Out:
#      start_station_id  Unnamed: 1
# 0                 120         NaN
# 1                 285         NaN
# 2                 251         NaN
# 3                 195         NaN
# 4                 453         NaN
# 5                 144         NaN
# 6                 266         NaN
# 7                 263         NaN
# 8                 216         NaN
# 9                 328         NaN
# 10                353         NaN
# 11                212         NaN
# 12                383         NaN
# 13                538         NaN
# 14                217         NaN
# 15                300         NaN
# 16                456         NaN
# 17                128         NaN
# 18                223         NaN
# 19                244         NaN
# 20                494         NaN
# 21                403         NaN
# 22                260         NaN
# 23                445         NaN
# 24                411         NaN
# 25                377         NaN
# ...

# %%
#count the number of trips
query1_4_1 = '''
SELECT COUNT(cartodb_id)
FROM fb55.citibike 
'''
get_data(query1_4_1)
# Out:
#    count  Unnamed: 1
# 0  46200         NaN

# %%
#average duration
query1_4_2 = '''
SELECT AVG(tripduration)
FROM fb55.citibike 
'''
get_data(query1_4_2)
# Out:
#           avg  Unnamed: 1
# 0  675.865823         NaN

# %%
#minimum duration
query1_4_3 = '''
SELECT MIN(tripduration)
FROM fb55.citibike 
'''
get_data(query1_4_3)
# Out:
#    min  Unnamed: 1
# 0   60         NaN

# %%
#maximum duration
query1_4_4 = '''
SELECT MAX(tripduration)
FROM citibike 
'''
get_data(query1_4_4)
# Out:
#      max  Unnamed: 1
# 0  43016         NaN

# %% [markdown]
# ### TASK 2 - Working with date/time

# %%
#Selecting trips started on Feb-02-2015 only
query2_1 = '''
SELECT *
FROM fb55.citibike
WHERE starttime between '2015-02-02 00:00:00+00' and '2015-02-02 23:59:59+00' '''
get_data(query2_1)
# Out:
#       the_geom           start_station_name  the_geom_webmercator  field_1  \
# 0          NaN              5 Ave & E 29 St                   NaN     7433
# 1          NaN         Allen St & Hester St                   NaN     7779
# 2          NaN            E 5 St & Avenue C                   NaN       11
# 3          NaN              9 Ave & W 16 St                   NaN      627
# 4          NaN              9 Ave & W 16 St                   NaN      991
# 5          NaN              W 33 St & 7 Ave                   NaN     1037
# 6          NaN              W 27 St & 7 Ave                   NaN     6510
# 7          NaN              E 11 St & 1 Ave                   NaN     6511
# 8          NaN         Peck Slip & Front St                   NaN     6512
# 9          NaN              E 16 St & 5 Ave                   NaN     6513
# 10         NaN              W 41 St & 8 Ave                   NaN     6514
# ...

# %%
# select trips started on weekends
query2_2 = '''
SELECT *
FROM fb55.citibike
WHERE EXTRACT(DOW FROM starttime) in (0,6)
'''
get_data(query2_2)
# Out:
#        the_geom        start_station_name  the_geom_webmercator  field_1  \
# 0           NaN        E 20 St & Park Ave                   NaN      175
# 1           NaN          W 43 St & 10 Ave                   NaN     1159
# 2           NaN         E 6 St & Avenue B                   NaN     2827
# 3           NaN           E 12 St & 3 Ave                   NaN     4961
# 4           NaN           W 41 St & 8 Ave                   NaN     6156
# 5           NaN           E 20 St & 2 Ave                   NaN    39894
# 6           NaN        Broadway & W 60 St                   NaN    41512
# 7           NaN         E 6 St & Avenue D                   NaN    41595
# 8           NaN            Great Jones St                   NaN    41806
# 9           NaN           W 13 St & 6 Ave                   NaN    42316
# 10          NaN          W 34 St & 11 Ave                   NaN    42532
# 11          NaN           W 41 St & 8 Ave                   NaN    42915
# ...

# %%
# calculate average weekend trip duration  
query2_2_1 = '''
SELECT AVG(tripduration)
FROM fb55.citibike
WHERE EXTRACT(DOW FROM starttime) in (0,6)
'''
get_data(query2_2_1)
# Out:
#           avg  Unnamed: 1
# 0  662.942181         NaN

# %%
# select trips started on Mon-Fri
query2_3 = '''
SELECT *
FROM fb55.citibike
WHERE EXTRACT(DOW FROM starttime) in (1,2,3,4,5)
'''
get_data(query2_3)
# Out:
#        the_geom              start_station_name  the_geom_webmercator  \
# 0           NaN                 5 Ave & E 29 St                   NaN
# 1           NaN            Allen St & Hester St                   NaN
# 2           NaN                 E 39 St & 3 Ave                   NaN
# 3           NaN                10 Ave & W 28 St                   NaN
# 4           NaN                  E 2 St & 2 Ave                   NaN
# 5           NaN                 1 Ave & E 44 St                   NaN
# 6           NaN                 W 45 St & 6 Ave                   NaN
# 7           NaN                 W 18 St & 6 Ave                   NaN
# 8           NaN                 E 58 St & 3 Ave                   NaN
# 9           NaN                 E 33 St & 5 Ave                   NaN
# 10          NaN                 W 31 St & 7 Ave                   NaN
# 11          NaN                 5 Ave & E 29 St                   NaN
# ...

# %%
# select trips started on Mon-Fri
query2_3_1 = '''
SELECT AVG(tripduration)
FROM fb55.citibike
WHERE EXTRACT(DOW FROM starttime) in (1,2,3,4,5)
'''
get_data(query2_3_1)
# Out:
#           avg  Unnamed: 1
# 0  681.052292         NaN

# %% [markdown]
# ### Task 3 - working in space

# %%
#showing the list of start station locations
query3_1 = '''
SELECT start_station_name
FROM fb55.citibike
GROUP BY start_station_name'''
get_data(query3_1)
# Out:
#                 start_station_name  Unnamed: 1
# 0             E 30 St & Park Ave S         NaN
# 1          Pearl St & Anchorage Pl         NaN
# 2                  W 56 St & 6 Ave         NaN
# 3                   West Thames St         NaN
# 4          Bank St & Washington St         NaN
# 5                  8 Ave & W 52 St         NaN
# 6               E 11 St & Broadway         NaN
# 7         DeKalb Ave & Skillman St         NaN
# 8    Atlantic Ave & Fort Greene Pl         NaN
# 9                Avenue D & E 8 St         NaN
# 10            S 3 St & Bedford Ave         NaN
# 11          W Broadway & Spring St         NaN
# 12                 2 Ave & E 31 St         NaN
# 13                 E 33 St & 5 Ave         NaN
# 14        MacDougal St & Prince St         NaN
# 15    Clermont Ave & Lafayette Ave         NaN
# 16          Barclay St & Church St         NaN
# 17          Forsyth St & Broome St         NaN
# 18                 W 13 St & 6 Ave         NaN
# ...

# %%
#showing the number of trips started per station
query3_2 = '''
SELECT start_station_name, COUNT(start_station_name) 
FROM fb55.citibike
GROUP BY start_station_name'''
get_data(query3_2)
# Out:
#                 start_station_name  count
# 0             E 30 St & Park Ave S    227
# 1          Pearl St & Anchorage Pl     54
# 2                  W 56 St & 6 Ave    164
# 3                   West Thames St    107
# 4          Bank St & Washington St    125
# 5                  8 Ave & W 52 St    133
# 6               E 11 St & Broadway    115
# 7         DeKalb Ave & Skillman St     10
# 8    Atlantic Ave & Fort Greene Pl     36
# 9                Avenue D & E 8 St     38
# 10            S 3 St & Bedford Ave     13
# 11          W Broadway & Spring St    159
# 12                 2 Ave & E 31 St    302
# 13                 E 33 St & 5 Ave    213
# 14        MacDougal St & Prince St    247
# 15    Clermont Ave & Lafayette Ave     25
# 16          Barclay St & Church St    244
# 17          Forsyth St & Broome St    212
# 18                 W 13 St & 6 Ave    257
# 19                 W 17 St & 8 Ave    288
# 20              E 20 St & Park Ave    218
# ...

# %%
#select only the station within 500m of Time square
#coordinate (40.7577, -73.9857)
query3_3 = '''
SELECT start_station_name, count(start_station_name)
FROM fb55.citibike
WHERE (6371 * acos(sin(radians(40.7577)) * sin(radians(start_station_latitude)) + 
cos(radians(40.7577)) * cos(radians(start_station_latitude)) * cos(radians(start_station_longitude) - radians(-73.9857)))) <= 0.5
GROUP BY start_station_name
'''
  
get_data(query3_3)
# Out:
#    start_station_name  count
# 0     W 45 St & 8 Ave    141
# 1     W 42 St & 8 Ave    221
# 2  Broadway & W 49 St    213
# 3     W 43 St & 6 Ave    112
# 4     W 41 St & 8 Ave    507
# 5     W 45 St & 6 Ave    141
# 6  Broadway & W 41 St    251

# %% [markdown]
# ### Task 4 - Putting it all together

# %%
#Find the station that had the longest average trip duration during weekends and within 500m of TimeSquare!
query4_1 = '''
SELECT start_station_name, count(start_station_name),avg(tripduration)
FROM fb55.citibike
WHERE (6371 * acos(sin(radians(40.7577)) * sin(radians(start_station_latitude)) + 
cos(radians(40.7577)) * cos(radians(start_station_latitude)) * cos(radians(start_station_longitude) - radians(-73.9857)))) <= 0.5 
and EXTRACT(DOW FROM starttime) in (0,6)
GROUP BY start_station_name
ORDER BY avg(tripduration) DESC LIMIT 1
'''
get_data(query4_1)
# Out:
#    start_station_name  count          avg
# 0  Broadway & W 49 St     48  1010.104167

# %% [markdown]
# ### EXTRA

# %%
#Extra: create lines for trips started from stations within 500m of Times Squares and lasted less than 2 hours. 
#The number of trips per each pair of stations are output as attributes of these lines.
query_e ='''
SELECT start_station_name, end_station_name, count(tripduration)
FROM fb55.citibike
WHERE (6371 * acos(sin(radians(40.7577)) * sin(radians(start_station_latitude)) + 
cos(radians(40.7577)) * cos(radians(start_station_latitude)) * cos(radians(start_station_longitude) - radians(-73.9857)))) <= 0.5
and tripduration < 7200
GROUP BY start_station_name, end_station_name
'''
  
get_data(query_e)
# Out:
#      start_station_name              end_station_name  count
# 0       W 42 St & 8 Ave              W 34 St & 11 Ave      2
# 1       W 41 St & 8 Ave              W 56 St & 10 Ave      5
# 2    Broadway & W 41 St               W 31 St & 7 Ave      2
# 3    Broadway & W 49 St         E 48 St & Madison Ave     13
# 4       W 41 St & 8 Ave               E 33 St & 5 Ave      4
# 5       W 41 St & 8 Ave            Broadway & W 24 St      4
# 6       W 42 St & 8 Ave               9 Ave & W 18 St      2
# 7    Broadway & W 49 St               9 Ave & W 22 St      1
# 8    Broadway & W 49 St            Broadway & E 22 St      2
# 9       W 42 St & 8 Ave               W 25 St & 6 Ave      2
# 10      W 43 St & 6 Ave       E 37 St & Lexington Ave      4
# 11   Broadway & W 41 St               E 25 St & 1 Ave      3
# 12      W 45 St & 6 Ave         Pershing Square North      1
# 13   Broadway & W 41 St        Forsyth St & Broome St      3
# ...
